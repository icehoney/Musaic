# %%
import librosa
import IPython

# %%
y, sr = librosa.load("../data/TheTourist-171222.mp3")

# %%
sr
# Out:
# 22050

# %%
y.shape
# Out:
# (6758028,)

# %%
y.shape[0]/sr
# Out:
# 306.4865306122449

# %%
IPython.display.Audio(data=y[1000000:1500000], rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
