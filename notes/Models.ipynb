# %%
import keras
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook as tqdm
import glob


# %matplotlib inline

# %%
df = pd.read_csv("../data/annotations_final.csv", sep = '\t')

# %%
mp3_files = df["mp3_path"].tolist()

# %%
mp3_files
# Out:
# ['f/american_bach_soloists-j_s__bach_solo_cantatas-01-bwv54__i_aria-30-59.mp3',
#  'f/american_bach_soloists-j_s__bach_solo_cantatas-01-bwv54__i_aria-146-175.mp3',
#  'f/american_bach_soloists-j_s__bach_solo_cantatas-01-bwv54__i_aria-262-291.mp3',
#  'f/american_bach_soloists-j_s__bach_solo_cantatas-01-bwv54__i_aria-291-320.mp3',
#  'f/american_bach_soloists-j_s__bach_solo_cantatas-01-bwv54__i_aria-320-349.mp3',
#  'c/lvx_nova-lvx_nova-01-contimune-30-59.mp3',
#  'c/lvx_nova-lvx_nova-01-contimune-175-204.mp3',
#  'c/lvx_nova-lvx_nova-01-contimune-233-262.mp3',
#  'c/lvx_nova-lvx_nova-01-contimune-291-320.mp3',
#  '0/american_bach_soloists-j_s__bach__cantatas_volume_v-01-gleichwie_der_regen_und_schnee_vom_himmel_fallt_bwv_18_i_sinfonia-0-29.mp3',
#  '0/american_bach_soloists-j_s__bach__cantatas_volume_v-01-gleichwie_der_regen_und_schnee_vom_himmel_fallt_bwv_18_i_sinfonia-117-146.mp3',
# ...

# %% [markdown]
# # X

# %%
def x_vec(npy_path):
    x = np.load(npy_path)
    mu = x.mean(axis=1)
    stde = x.std(axis=1)
    mx = x.max(axis = 1)
    x_vec = np.concatenate((mu, stde, mx))
    return x_vec

# %%
X = np.zeros((len(npy_files),288))
i = 0
for mp3_file in tqdm(mp3_files):
    npy_file = "../data/Melspecs/" + mp3_file[:-3] + "npy"
    X[i] = x_vec(npy_file)
    i += 1
# Out:
# A Jupyter Widget

# %%
np.save("../data/Train/X.npy", X)

# %%
plt.imshow(X, aspect = "auto")
